# %%
from typing import List

# %%
class Solution:
    def generate(self, numRows: int) -> List[List[int]]:
        pascal_list = [[1],[1,1]]
        counter = 1

        if numRows == 1:
            return [pascal_list[0]]
            
        for i in range(numRows - 2):
            p_list = []
            for j in range(len(pascal_list[counter])-1):
                if j == 0:
                   p_list.append(1)
                p_list.append(pascal_list[counter][j] + pascal_list[counter][j+1])
            p_list.append(1)
            pascal_list.append(p_list)
            counter +=1
        return pascal_list

sol = Solution()
sol.generate(1)
# Out:
# [[1]]

# %%
m = [1,3,3,1]
p_list=[]
for i in range(len(m)-1):
    if i == 0:
        p_list.append(1)
    p_list.append(m[i] + m[i+1])
p_list.append(1)
p_list
# Out:
# [1, 4, 6, 4, 1]

# %%
pascal_list=[[1],[1,2],[1,2,3,4]]
pascal_list[2][3]
# Out:
# 4
